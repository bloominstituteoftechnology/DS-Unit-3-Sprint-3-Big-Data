# %%
from load_data import X,y, X_train, X_test, y_train, y_test
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

X.head()

#print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
#          D1        D2    D3   D4        D5        D6        D7        D8  \
# 0  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166  0.585445
# 1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105  0.411754
# 2  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453  0.517720
# 3  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606  0.288764
# 4  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361  0.303809
#
#          D9       D10  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.743663  0.243144  ...      0      0      0      0      0      0      0
# 1  0.836582  0.106480  ...      1      1      1      1      0      1      0
# 2  0.679051  0.352308  ...      0      0      0      0      0      0      0
# 3  0.805110  0.208989  ...      0      0      0      0      0      0      0
# 4  0.812646  0.125177  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# ...

# %%
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.14)


B = 6
n = int(np.divide(X.shape[0]-1, B))

# Define an estimator and param_grid
pipe = Pipeline(
    ('scale', RobustScaler()), 
    ('reduce_dim', SelectKBest(f_regression)), 
    ('classifier', SGDClassifier(X_train, y_train, verbose=10)))

param_grid = {
    'reduce_dim__k': range(B, n), 
    'classifier__loss': ['log', 'modified_huber']
}

# Fit on the train set, with grid search cross-validation
gs = GridSearchCV(pipe, param_grid=param_grid, cv=3, 
                  scoring='neg_log_loss', 
                  verbose=1, n_jobs=2)

gs.fit(X_train, y_train)
validation_score = gs.best_score_
print()
print('Cross-Validation Score:', -validation_score)
print()
print('Best estimator:', gs.best_estimator_)
print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py in _get_penalty_type(self, penalty)
#     208         try:
# --> 209             return PENALTY_TYPES[penalty]
#     210         except KeyError:
#
# ...
