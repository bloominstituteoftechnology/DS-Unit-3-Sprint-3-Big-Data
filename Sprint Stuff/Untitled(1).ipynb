# %% [markdown]
# ## Pt_1 (importing and looking at youtube comments)

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('Youtube*.csv')
df.compute()
# We do indeed have five columns, but i guess it doesnt even count shape, gimme one sec..
# Out:
#                                       COMMENT_ID                AUTHOR  \
# 0    LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1    LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A           adam riyati
# 2    LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8      Evgeny Murashkin
# 3            z13jhp0bxqncu512g22wvzkasxmvvzjaz04       ElNino Melendez
# 4            z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# 5    LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc          Jason Haddad
# 6            z13lfzdo5vmdi1cm123te5uz2mqig1brz04        ferleck ferles
# 7          z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k          Bob Kanowski
# 8            z13ttt1jcraqexk2o234ghbgzxymz1zzi04                  Cony
# 9            z12avveb4xqiirsix04chxviiljryduwxg0           BeBe Burkey
# 10         z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k             Huckyduck
# 11             z13xit5agm2zyh4f523rst2gowmbx5bml           Lone Twistt
# ...

# %%
df.count().compute()
# there we go! For some reason data has a lot of NAs, which is weird since comments are timestampped but w/e
# Out:
# COMMENT_ID    1956
# AUTHOR        1956
# DATE          1711
# CONTENT       1956
# CLASS         1956
# dtype: int64

# %%
df2 = df[df.CLASS == 1]
df3 = df[df.CLASS == 0]

# %%
df2.compute()
# 1005, hooray!
# Out:
#                                       COMMENT_ID  \
# 0    LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU
# 1    LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A
# 2    LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8
# 3            z13jhp0bxqncu512g22wvzkasxmvvzjaz04
# 4            z13fwbwp1oujthgqj04chlngpvzmtt3r3dw
# 5    LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc
# 6            z13lfzdo5vmdi1cm123te5uz2mqig1brz04
# 8            z13ttt1jcraqexk2o234ghbgzxymz1zzi04
# 9            z12avveb4xqiirsix04chxviiljryduwxg0
# 10         z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k
# 11             z13xit5agm2zyh4f523rst2gowmbx5bml
# 12             z13pejoiuozwxtdu323dspopnri4xts0f
# 13         z121zxaxsq25z5k5o04ch1o5jqqfij3gtm40k
# 14         z12oglnpoq3gjh4om04cfdlbgp2uepyytpw0k
# 15           z13phrmwrkfisn5er22eyrbpbvaiwfvwf04
# 17           z13vxpnoxsyeuv2jr04cctprprb1slnxdf4
# 18         z12qth5j0ob1fx3q404chvy4fz32tbkpllk0k
# 19           z13etj0bclzfztuwc04cgfvrgmf3fvjor1g
# ...

# %%
df3.compute()
# 951, also yay(? half the internet is spam, maybe not yay)
# Out:
#                                       COMMENT_ID                 AUTHOR  \
# 7          z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k           Bob Kanowski
# 16           z13bgdvyluihfv11i22rgxwhuvabzz1os04            Zielimeek21
# 20           z12axnji5w2axxht522thb3bktvqjdlbp04           zhichao wang
# 23         z12ntlcqht2bvjewi04cf1up0xjvs5lq3mc0k               Owen Lai
# 28         z13tj514otzlurfbc04ccjwhrnmej1iihqw0k          Brandon Pryor
# 31           z13autsqgzblcx3w104chr4r2kexd10rxc0           DropShotSk8r
# 34           z13kxpqqssa0hlryd04cc1dxeyyngljjngk           Tasha Lucius
# 35         z13iuzxwamqhzppyp04cdz1amyzpfdnpdns0k        Jason Provencal
# 46             z121znjjloycwtjf2233dfo5esfggn3lj               crestpee
# 48         z12stpyqaonsercxw04cjbr4dlnrxd34soo0k                Phuc Ly
# 49           z13nvr2xayrwffsio04cj3zwyuf3vb1imdg           Milan George
# 51             z13ucxa51rnftvu2j22if5oihq2qipjlp                 Kochos
# ...

# %%
df4 = df[df.CONTENT.str.contains('check', case = False)]
df4.compute()
# kk so thats 461 spam and 19 non
# Out:
#                                       COMMENT_ID                AUTHOR  \
# 0    LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1    LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A           adam riyati
# 4            z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# 5    LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc          Jason Haddad
# 7          z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k          Bob Kanowski
# 8            z13ttt1jcraqexk2o234ghbgzxymz1zzi04                  Cony
# 9            z12avveb4xqiirsix04chxviiljryduwxg0           BeBe Burkey
# 15           z13phrmwrkfisn5er22eyrbpbvaiwfvwf04  Gaming and Stuff PRO
# 16           z13bgdvyluihfv11i22rgxwhuvabzz1os04           Zielimeek21
# 20           z12axnji5w2axxht522thb3bktvqjdlbp04          zhichao wang
# 23         z12ntlcqht2bvjewi04cf1up0xjvs5lq3mc0k              Owen Lai
# 24   LZQPQhLyRh9EXArr4ZnVcDonSbvSMHKYOT24e_qR6fE           ||GuitarZ||
# ...

# %%
df4.CLASS.value_counts().compute()
# Out:
# 1    461
# 0     19
# Name: CLASS, dtype: int64

# %%
from bokeh.plotting import figure, output_file, show
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = df.compute()
df2.plot(kind = 'line', x='DATE', y = 'CLASS')
//errrrr, ok but

# %% [markdown]
# ## Pt_2 (Big Data options)

# %% [markdown]
#     So far, I've really enjoyed this high level overview of the Big Data options for data analysis, it's really opened up my world a bit.  So Far, I would prefer to use Databricks just for its notebook and the ease of switching languages/clusters and the user friendly interface, which I absolutely love and clearly has a lot of thought and care behind it, but the raw power of Amazon SageMaker makes you feel like jumping from driving a truck to driving a plane.  Its so smooth and responsive that for tasks that would require large data, complex models, or just a ton of recursive operations, I really couldn't consider using anything else.
#
#     I wish we had spent a little more time working with numba, as it seems really awesome, but I guess I cant be lazy *all* the time, so at least I know what to work on learning more of!  In terms of languages python feels comfortable for me (even if i cant make a function to save my life), but scala is coming up as a close contender.  I still cant make a function in it worth a dang, but I do really enjoy it.  Dask is similar enough to be readable but just slightly different enough to feel frustrating, but it also has a lot of uses, and like everything, im sure it gets better with time.
