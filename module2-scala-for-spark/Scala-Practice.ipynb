// %%
1+1
// Out:
// VBox()
// 2

// %%
println("Hello World!")
// Out:
// VBox()
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1551216679750_0002</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-8-227.us-west-2.compute.internal:20888/proxy/application_1551216679750_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-8-227.us-west-2.compute.internal:8042/node/containerlogs/container_1551216679750_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// Hello World!

// %%
3 + 3
3 * 3
math.pow(3, 3)
// Out:
// VBox()
// res2: Int = 6
// res3: Int = 9
// res4: Double = 27.0

// %%
// This is a single-line comment
// Out:
// VBox()

// %%
/*
This is a multi-line comment.
*/
// Out:
// VBox()

// %%
// Printing and forcing a newline on next print
println("Hello World!")
println(10)
// Hello World!
//10
// Out:
// VBox()
// Hello World!
// 10

// %%
// Printing without forcing a newline on next print
print("Hello World")
print(10)
// Hellow World10
// Out:
// VBox()
// Hello World10

// %%
// Declaring values is done using either var or val.
// val declarations are immutable, but vars are mutable. Immutability is
// a good thing.
val x = 10 // x is now 10
// x = 20     // error: reassignment to val
var y = 10
y = 20     // y is now 20
// Out:
// VBox()
// x: Int = 10
// y: Int = 10
// y: Int = 20

// %%
/*
Scala is a statically typed language, yet note that in the above declarations,
I did not specify a type. This is due to a language feature called type
inference. In most cases, Scala compiler can guess what the type of a variable
is, so the user doesn't have to type it every time. An explicit declaration of
variable type follows below:
*/
val z: Int = 10
val a: Double = 1.0
// Out:
// VBox()
// z: Int = 10
// a: Double = 1.0

// %%
// Notice automatic conversion from Int to Double, result is 10.0, not 10
val b: Double = 10
// Out:
// VBox()
// b: Double = 10.0

// %%
// Boolean values
true
false
// Out:
// VBox()
// res39: Boolean = true
// res40: Boolean = false

// %%
// Boolean operations
!true          // false
!false         // true
true == false  // false
10 > 5         // true
// Out:
// VBox()
// res42: Boolean = false
// res43: Boolean = true
// res44: Boolean = false
// res45: Boolean = true

// %%
// Do some Math
1 + 1     // 2
2 - 1     // 1
5 * 3     // 15
6 / 2     // 3
6 / 4     // 1
6.0 / 4   // 1.5
6 / 4.0   // 1.5
// Out:
// VBox()
// res47: Int = 2
// res48: Int = 1
// res49: Int = 15
// res50: Int = 3
// res51: Int = 1
// res52: Double = 1.5
// res53: Double = 1.5

// %%
// Evaluating an expression in the REPL gives you the type and value of the result
1 + 7
/* The above line results in:
scala> 1 + 7
res54: Int = 8

This means the result of evaluating 1 + 7 is an object of type Int with a
value of 8.

Note that "res59" is a sequentially generated variable name to store the
results of the expressions I typed.
*/
// Out:
// VBox()
// res59: Int = 8

// %%
"Scala strings are surrounded by double quotes"
'a'  // A Scala Char
// 'Single quote strings don't exist' <= This causes an error
// Out:
// VBox()
// res68: String = Scala strings are surrounded by double quotes
// res69: Char = a

// %%
// Strings have the usual Java methods defined on them
"hello world".length
"hello world".substring(2, 6)
"hello world".replace("C", "3")
// Out:
// VBox()
// res73: Int = 11
// res74: String = "llo "
// res75: String = hello world

// %%
// Strings also have some additional Scala methods. See also: scala.collection.immutable.StringOps
"hello world".take(5)
"hello world".drop(5)
// Out:
// VBox()
// res77: String = hello
// res78: String = " world"

// %%
// String interpolation: notice the prefix "s"
val n = 45
s"We have $n apples"  // => "We have 45 apples"
// Out:
// VBox()
// n: Int = 45
// res80: String = We have 45 apples

// %%
// Expressions inside interpolated strings are also possible
s"Power of 2: ${math.pow(2, 2)}"     // "Power of 2: 4"
// Out:
// VBox()
// res82: String = Power of 2: 4.0

// %%
// Some characters need to be "escaped", e.g. a double quote inside a string:
"They stood outside the \"Rose and Crown\""     // => "They stood outside the "Rose and Crown""
// Out:
// VBox()
// res84: String = They stood outside the "Rose and Crown"

// %%
////
// 2. Functions
////

// Functions are defined like so:
//
// def functionName(args...): ReturnType = { body... }
//
// Notice the omission of the "return" keyword. In Scala, the last expression in the function block is the
// return value.
def sumOfSquares(x: Int, y: Int): Int = {
    val x2 = x * x
    val y2 = y * y
    x2 + y2
}
// Out:
// VBox()
// sumOfSquares: (x: Int, y: Int)Int

// %%
// The {} can be omitted if the function body is a single expression:
def sumOfSquaresShort(x: Int, y: Int): Int = x * x + y * y
// Out:
// VBox()
// sumOfSquaresShort: (x: Int, y: Int)Int

// %%
// Syntax for calling functions is familiar:
sumOfSquares(3, 4)    // => 25
// Out:
// VBox()
// res97: Int = 25
