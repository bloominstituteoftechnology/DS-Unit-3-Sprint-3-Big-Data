// %%
1 + 1
// Out:
// VBox()
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>2</td><td>application_1551205248343_0003</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-30-244.us-east-2.compute.internal:20888/proxy/application_1551205248343_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-30-244.us-east-2.compute.internal:8042/node/containerlogs/container_1551205248343_0003_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// res1: Int = 2

// %%
println("Hello World")
// Out:
// VBox()
// Hello World

// %%
res1 + res1 + res1
// Out:
// VBox()
// res3: Int = 6

// %%
3 + 3
3 * 3
math.pow(3, 3)
// Out:
// VBox()
// res4: Int = 6
// res5: Int = 9
// res6: Double = 27.0
