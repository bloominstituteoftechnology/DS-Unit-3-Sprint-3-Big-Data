// %% [markdown]
// # Scala the hard way

// %%
1 + 1
// Out:
// VBox()
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1551205288431_0001</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-14-55.us-west-2.compute.internal:20888/proxy/application_1551205288431_0001/">Link</a></td><td><a target="_blank" href="http://ip-172-31-14-55.us-west-2.compute.internal:8042/node/containerlogs/container_1551205288431_0001_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// res1: Int = 2

// %% [markdown]
// ## Basics

// %%
println("Hello world!")
println(10)
// Out:
// VBox()
// Hello world!
// 10

// %%
print("Hello world")
print(10)
// Out:
// VBox()
// Hello world10

// %%
val x = 10
x = 20
// Out:
// VBox()
// <console>:25: error: reassignment to val
//        x = 20
//          ^

// %%
var y = 10
y = 20
// Out:
// VBox()
// y: Int = 10
// y: Int = 20

// %%
val z: Int = 10
val a: Double = 1.0
// Out:
// VBox()
// z: Int = 10
// a: Double = 1.0

// %%
val b: Double = 20
// Out:
// VBox()
// b: Double = 20.0

// %%
true
false
// Out:
// VBox()
// res20: Boolean = true
// res21: Boolean = false

// %%
!true
!false
true == false
10 > 5
// Out:
// VBox()
// res22: Boolean = false
// res23: Boolean = true
// res24: Boolean = false
// res25: Boolean = true

// %%
1 + 1
2 - 1
5 * 3
6 / 2
6 / 4
6.0 / 4
6 / 4.0
// Out:
// VBox()
// res27: Int = 2
// res28: Int = 1
// res29: Int = 15
// res30: Int = 3
// res31: Int = 1
// res32: Double = 1.5
// res33: Double = 1.5

// %%
"hello world".length
"hello world".substring(2,6)
"hello world".replace("C","3")
// Out:
// VBox()
// res34: Int = 11
// res35: String = "llo "
// res36: String = hello world

// %%
"hello world".take(5)
"hello world".drop(5)
// Out:
// VBox()
// res37: String = hello
// res38: String = " world"

// %%
val n = 99
s"I got $n problems, but Scala ain't one"
// Out:
// VBox()
// n: Int = 99
// res39: String = I got 99 problems, but Scala ain't one

// %%
s"By the power of 2: ${math.pow(2,2)}"
// Out:
// VBox()
// res42: String = By the power of 2: 4.0

// %%
"What do you mean, \"escaped\"?"
// Out:
// VBox()
// res43: String = What do you mean, "escaped"?

// %% [markdown]
// # Functions

// %%
def sumOfSquares(x: Int, y: Int): Int = {
    val x2 = x * x
    val y2 = y * y
    x2 + y2
}
sumOfSquares(3,4)
// Out:
// VBox()
// sumOfSquares: (x: Int, y: Int)Int
// res44: Int = 25

// %%
def subtract(x: Int, y: Int): Int = x - y
subtract(10,3)
subtract(y=10, x=3)
// Out:
// VBox()
// subtract: (x: Int, y: Int)Int
// res45: Int = 7
// res46: Int = -7

// %%
def sq(X: Int) = x * x
// Out:
// VBox()
// sq: (X: Int)Int

// %%
def addWithDefault(x: Int, y: Int = 5) = x + y
addWithDefault(1,2)
addWithDefault(1)
// Out:
// VBox()
// addWithDefault: (x: Int, y: Int)Int
// res47: Int = 3
// res48: Int = 6

// %%
(x: Int) => x * x
// Out:
// VBox()
// res49: Int => Int = <function1>

// %%
val sq: Int => Int = x => x * x
sq(10)
// Out:
// VBox()
// sq: Int => Int = <function1>
// res50: Int = 100

// %%
val addOne: Int => Int = _ + 1
val weirdSum: (Int, Int) => Int = (_ * 2 + _ * 3)
addOne(5)
weirdSum(2,4)
// Out:
// VBox()
// addOne: Int => Int = <function1>
// weirdSum: (Int, Int) => Int = <function2>
// res51: Int = 6
// res52: Int = 16

// %% [markdown]
// ## Flow control

// %%
1 to 5
// Out:
// VBox()
// res53: scala.collection.immutable.Range.Inclusive = Range(1, 2, 3, 4, 5)

// %%
val r = 1 to 5
// Out:
// VBox()
// r: scala.collection.immutable.Range.Inclusive = Range(1, 2, 3, 4, 5)

// %%
r.foreach(println)
// Out:
// VBox()
// 1
// 2
// 3
// 4
// 5

// %%
r foreach println
// Out:
// VBox()
// 1
// 2
// 3
// 4
// 5

// %%
(5 to 1 by -1) foreach (println)
// Out:
// VBox()
// 5
// 4
// 3
// 2
// 1

// %%
def showNumbersInRange(a: Int, b: Int): Unit = {
    print(a)
    if (a < b)
        showNumbersInRange(a + 1, b)
}
showNumbersInRange(1, 14)
// Out:
// VBox()
// showNumbersInRange: (a: Int, b: Int)Unit
// 1234567891011121314

// %%
val x = 10

if (x == 1) println("yeah")
if (x == 10) println("yeah")
if (x == 11) println("yeah")
if (x == 11) println("yeah") else println("nay")

println(if (x == 10) "yeah" else "nope")
val text = if (x==10) "yeah" else "nope"
// Out:
// VBox()
// x: Int = 10
// yeah
// nay
// yeah
// text: String = yeah

// %% [markdown]
// ## Data structures

// %%
val a = Array(1,2,3,5,8,13)
a(0)
a(3)
// Out:
// VBox()
// a: Array[Int] = Array(1, 2, 3, 5, 8, 13)
// res68: Int = 1
// res69: Int = 5

// %%
a(21)
// Out:
// VBox()
// java.lang.ArrayIndexOutOfBoundsException: 21
//   ... 50 elided

// %%
val s = Set(1, 3, 7)
s(0)
s(1)
// Out:
// VBox()
// s: scala.collection.immutable.Set[Int] = Set(1, 3, 7)
// res71: Boolean = false
// res72: Boolean = true

// %%
(1, 2)
(4, 3, 2)
(1, 2, "three")
(a, 2, "three")
// Out:
// VBox()
// res73: (Int, Int) = (1,2)
// res74: (Int, Int, Int) = (4,3,2)
// res75: (Int, Int, String) = (1,2,three)
// res76: (Array[Int], Int, String) = (Array(1, 2, 3, 5, 8, 13),2,three)

// %%
val divideInts = (x: Int, y: Int) => (x / y, x % y)
divideInts(10,3)
// Out:
// VBox()
// divideInts: (Int, Int) => (Int, Int) = <function2>
// res77: (Int, Int) = (3,1)

// %%
val d = divideInts(10,3)
d._1
d._2
// Out:
// VBox()
// d: (Int, Int) = (3,1)
// res78: Int = 3
// res79: Int = 1

// %%
val (div, mod) = divideInts(10,3)
div
mod
// Out:
// VBox()
// div: Int = 3
// mod: Int = 1
// res80: Int = 3
// res81: Int = 1

// %% [markdown]
// ## Functional programming

// %%
val add10: Int => Int = _ + 10
List(1, 2, 3) map add10
// Out:
// VBox()
// add10: Int => Int = <function1>
// res82: List[Int] = List(11, 12, 13)

// %%
List(1, 2, 3) map (_ + 10)
// Out:
// VBox()
// res83: List[Int] = List(11, 12, 13)

// %%
List("Dom", "Bob", "Natalia") foreach println
// Out:
// VBox()
// Dom
// Bob
// Natalia

// %%
s.map(sq)
// Out:
// VBox()
// res85: scala.collection.immutable.Set[Int] = Set(1, 9, 49)

// %%
val sSquared = s map(sq)
// Out:
// VBox()
// sSquared: scala.collection.immutable.Set[Int] = Set(1, 9, 49)

// %%
sSquared.filter(_ < 10)
// Out:
// VBox()
// res86: scala.collection.immutable.Set[Int] = Set(1, 9)

// %%
sSquared.reduce (_+_)
// Out:
// VBox()
// res87: Int = 59

// %%
List(1,2,3) filter (_>2)
// Out:
// VBox()
// res88: List[Int] = List(3)

// %%
case class Person(name: String, age: Int)

List(
    Person(name="Dom", age=23),
    Person(name="Bob", age=30)
).filter(_.age>25)
// Out:
// VBox()
// defined class Person
// res92: List[Person] = List(Person(Bob,30))

// %%
val aListOfNumbers = List(1, 2, 3, 4, 10, 20, 100)
aListOfNumbers foreach (x => println(x))
aListOfNumbers foreach println
// Out:
// VBox()
// aListOfNumbers: List[Int] = List(1, 2, 3, 4, 10, 20, 100)
// 1
// 2
// 3
// 4
// 10
// 20
// 100
// 1
// 2
// 3
// 4
// 10
// 20
// 100

// %% [markdown]
// ## Misc

// %%
import scala.collection.immutable.List
// Out:
// VBox()
// import scala.collection.immutable.List

// %%
import scala.collection.immutable._
// Out:
// VBox()
// import scala.collection.immutable._

// %%
import scala.collection.immutable.{List,Map}
// Out:
// VBox()
// import scala.collection.immutable.{List, Map}

// %%
import scala.collection.immutable.{List => ImmutableList}
// Out:
// VBox()
// import scala.collection.immutable.{List=>ImmutableList}
