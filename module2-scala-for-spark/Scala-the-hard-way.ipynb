// %%
1 + 1
// Out:
// VBox()
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1551209566230_0002</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-2-78.us-east-2.compute.internal:20888/proxy/application_1551209566230_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-2-78.us-east-2.compute.internal:8042/node/containerlogs/container_1551209566230_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// res1: Int = 2

// %%
println("Hello World")

// %%
res0
// Out:
// VBox()
// res2: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@928235b

// %%
res1
// Out:
// VBox()
// res3: Int = 2

// %%
:type (true, 2.0)
// Out:
// VBox()
// <console>:1: error: illegal start of definition
// :type (true, 2.0)
// ^

// %%
save /sites/repl-test.scala
// Out:
// VBox()
// <console>:24: error: not found: value save
//        save /sites/repl-test.scala
//        ^
// <console>:24: error: not found: value sites
//        save /sites/repl-test.scala
//              ^
// <console>:24: error: not found: value repl
//        save /sites/repl-test.scala
//                    ^
// <console>:24: error: not found: value test
//        save /sites/repl-test.scala
//                         ^

// %%
println("Hello World!")
println(10)
// Out:
// VBox()
// Hello World!
// 10

// %%
print("Hello World!")
print(10)
// Out:
// VBox()
// Hello World!10

// %%
val x = 10 // x is now 10
x = 20
// Out:
// VBox()
// <console>:25: error: reassignment to val
//        x = 20
//          ^

// %%
var y = 10
y = 20
// Out:
// VBox()
// y: Int = 10
// y: Int = 20

// %%
val z: Int = 10
val a: Double = 1.0
// Out:
// VBox()
// z: Int = 10
// a: Double = 1.0

// %%
val b: Double = 10
// Out:
// VBox()
// b: Double = 10.0

// %%
true
false
// Out:
// VBox()
// res12: Boolean = true
// res13: Boolean = false

// %%
!true
!false
true == false
10 > 5
// Out:
// VBox()
// res14: Boolean = false
// res15: Boolean = true
// res16: Boolean = false
// res17: Boolean = true

// %%
1 + 1
2 - 1
5 * 3
6 / 2
6 / 4
6.0 / 4
6 / 4.0
// Out:
// VBox()
// res18: Int = 2
// res19: Int = 1
// res20: Int = 15
// res21: Int = 3
// res22: Int = 1
// res23: Double = 1.5
// res24: Double = 1.5

// %%
 1 + 7
// Out:
// VBox()
// res25: Int = 8

// %%
"Scala strings are surrounded by quotes"
'a'
// Out:
// VBox()
// res26: String = Scala strings are surrounded by quotes
// res27: Char = a

// %%
"hello world".length
"hello world".substring(2,6)
"hello world".replace("c", "3")
// Out:
// VBox()
// res28: Int = 11
// res29: String = "llo "
// res30: String = hello world

// %%
"hello world".take(3)
"hello world".drop(2)
// Out:
// VBox()
// res33: String = hel
// res34: String = llo world

// %%
val n = 45
s"We have $n apples"
// Out:
// VBox()
// n: Int = 45
// res35: String = We have 45 apples

// %%
val a = Array(11,9,6)
s"My second daughter is ${a(0) - a(2)} years old."
s"We have double the amount of ${n / 2.0} in apples."
s"Power of 2: ${math.pow(2,2)}"

//Formatting with interpolated strings with the prefix "f"
f"Power of 5: ${math.pow(5,2)}%1.0f"
f"Square root of 122: ${math.sqrt(122)}%1.4f"
// Out:
// VBox()
// a: Array[Int] = Array(11, 9, 6)
// res44: String = My second daughter is 5 years old.
// res45: String = We have double the amount of 22.5 in apples.
// res46: String = Power of 2: 4.0
// res49: String = Power of 5: 25
// res50: String = Square root of 122: 11.0454

// %%
raw"New line feed: \n. Carriage return: \r"
// Out:
// VBox()
// res51: String = New line feed: \n. Carriage return: \r

// %%
"They stood outside the \"Rose and Crown\""
// Out:
// VBox()
// res52: String = They stood outside the "Rose and Crown"

// %%
val html = """
<form id="daform">
<p>Press belo', Joe</p>
<input type="submit">
</form>
"""
// Out:
// VBox()
// html: String =
// "
// <form id="daform">
// <p>Press belo', Joe</p>
// <input type="submit">
// </form>
// "

// %%
def sumOfSquares(x: Int, y: Int): Int = {
    val x2 = x * x
    val y2 = y * y
    x2 + y2
}
// Out:
// VBox()
// sumOfSquares: (x: Int, y: Int)Int

// %%
sumOfSquares(3,6)
// Out:
// VBox()
// res54: Int = 45

// %%
def subtract(x: Int, y: Int): Int = x - y
// Out:
// VBox()
// subtract: (x: Int, y: Int)Int

// %%
subtract(10,3)
subtract(5*2, 18/3)
// Out:
// VBox()
// res56: Int = 7
// res57: Int = 4

// %%
def sq(x: Int) = x * x
// Out:
// VBox()
// sq: (x: Int)Int

// %%
sq(17)
// Out:
// VBox()
// res58: Int = 289

// %%
def addWithDefault(x: Int, y: Int = 5) = x + y
addWithDefault(1,2)
addWithDefault(1)
// Out:
// VBox()
// addWithDefault: (x: Int, y: Int)Int
// res59: Int = 3
// res60: Int = 6

// %%
(x: Int) => x * x
// Out:
// VBox()
// res61: Int => Int = <function1>

// %%
val sq: Int => Int = x => x * x
// Out:
// VBox()
// sq: Int => Int = <function1>

// %%
sq(14)
// Out:
// VBox()
// res62: Int = 196

// %%
val addOne: Int => Int = _ + 1
val weirdSum: (Int, Int) => Int = (_ * 2 + _ * 3)
// Out:
// VBox()
// addOne: Int => Int = <function1>
// weirdSum: (Int, Int) => Int = <function2>

// %%
addOne(5)
weirdSum(2,4)
// Out:
// VBox()
// res63: Int = 6
// res64: Int = 16

// %%
def foo(x: Int): Int = {
    val anonFunc: Int => Int = { z =>
    if (z > 5)
        return z
    else
        z + 2
    }
    anonFunc(x)
}
// Out:
// VBox()
// foo: (x: Int)Int

// %%
foo(3)
// Out:
// VBox()
// res65: Int = 5

// %%
foo 12
// Out:
// VBox()
// <console>:1: error: ';' expected but integer literal found.
// foo 12
//     ^

// %%
foo(12)
// Out:
// VBox()
// res66: Int = 12
